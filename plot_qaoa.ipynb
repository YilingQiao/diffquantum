# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from ours_spectral import OurSpectral
# from maxcut_pennylane import qaoa_maxcut

# n_layers = 2
# n_parameters = n_layers * 2
# n_epoch = 30

# n_gate_run = 20
# losses = []
# for i in range(n_gate_run):
#     _, bit_strings, loss = qaoa_maxcut(n_epoch, n_layers=n_layers)
#     losses.append(loss)
# np_loss = np.array(losses)


# ours_legendre = OurSpectral(n_basis=n_parameters, basis='Legendre', n_epoch=n_epoch)
# # ours_legendre = OurSpectral(n_basis=n_parameters, basis='Fourier', n_epoch=n_epoch)
# state, prob = ours_legendre.demo_qaoa_max_cut4()
# loss_legendre = ours_legendre.losses_energy

# n = np.array(bit_strings).sum()
# samples = []
# for i in range(len(prob)):
#     samples += [i] * int(prob[i] * n)


# plt.clf()
# plt.plot(losses, label='QAOA')
# plt.plot(loss_legendre, label='Legendre')
# plt.legend(loc="upper right")
# plt.savefig("{}_{}.png".format(ours_legendre.log_dir, 'loss_qaoa'))

# xticks = range(0, 16)
# xtick_labels = list(map(lambda x: format(x, "04b"), xticks))
# bins = np.arange(0, 17) - 0.5
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4))
# plt.subplot(1, 2, 1)
# plt.title("Ours")
# plt.xlabel("bitstrings")
# plt.ylabel("freq.")
# plt.xticks(xticks, xtick_labels, rotation="vertical")
# plt.hist(samples, bins=bins)
# plt.subplot(1, 2, 2)
# plt.title("QAOA")
# plt.xlabel("bitstrings")
# plt.ylabel("freq.")
# plt.xticks(xticks, xtick_labels, rotation="vertical")
# plt.hist(bit_strings, bins=bins)
# plt.tight_layout()
# plt.savefig("{}_{}.png".format(ours_legendre.log_dir, 'qaoa_hist'))



import numpy as np
import matplotlib.pyplot as plt
from ours_spectral import OurSpectral
from grape import Grape
from maxcut_pennylane import qaoa_maxcut

# n_parameters = 4
# n_epoch = 100
# taylor_terms = 20

n_layers = 2
n_parameters = n_layers * 2
n_epoch = 100
n_runs = 3
xx = np.arange(n_epoch)

plt.clf()
colors = [
    [0, 0.45, 0.74],
    [0.85, 0.33, 0.1],
    [0.9290, 0.6940, 0.1250],
    [0.4940, 0.1840, 0.5560],
    [0.4660, 0.6740, 0.1880]
]

params = {'legend.fontsize': 20,
          'figure.figsize': (16, 12),
         'axes.labelsize': 20,
         'axes.titlesize': 20,
         'xtick.labelsize':20,
         'ytick.labelsize':20}
plt.rcParams.update(params)
plt.grid(alpha=0.3)

all_losses = []
all_mean = []
all_std = []

# QAOA

n_gate_run = 20
losses = []
for i in range(n_gate_run):
    _, bit_strings, loss = qaoa_maxcut(n_epoch, n_layers=n_layers)
    losses.append(loss)
np_loss = np.array(losses) + 4.
mean_ = np_loss.mean(0)
std_ = np_loss.std(0) 
color = colors[2]
plt.plot(mean_, color=color, label='Gate Model')
plt.fill_between(xx, np.maximum(mean_-std_, mean_/3), mean_+std_, color=color, alpha=0.2)
all_mean.append(mean_)
all_std.append(std_)


# grape
# grape = Grape(taylor_terms=taylor_terms, n_step=n_parameters, n_epoch=n_epoch)
# losses = []
# for i in range(n_runs):
#     grape.demo_TIM()
#     losses.append(grape.losses_energy.copy())
# losses = np.array(losses)
# mean_ = losses.mean(0)
# std_ = losses.std(0) 
# color = colors[2]
# plt.plot(mean_, color=color, label='grape')
# plt.fill_between(xx, np.maximum(mean_-std_, mean_/3.0), mean_+std_, color=color, alpha=0.2)
# all_mean.append(mean_)
# all_std.append(std_)

# Fourier
ours_fourier = OurSpectral(n_basis=n_parameters, basis='Fourier', n_epoch=n_epoch)
losses = []
for i in range(n_runs):
    state, prob = ours_fourier.demo_qaoa_max_cut4()
    losses.append(ours_fourier.losses_energy.copy())
losses = np.array(losses) + 4.
mean_ = losses.mean(0)
std_ = losses.std(0) 
color = colors[1]
plt.plot(mean_, color=color, label='Ours Fourier')
plt.fill_between(xx, np.maximum(mean_-std_, mean_/3), mean_+std_, color=color, alpha=0.2)
all_mean.append(mean_)
all_std.append(std_)


# Legendre
ours_legendre = OurSpectral(n_basis=n_parameters, basis='Legendre', n_epoch=n_epoch)
losses = []
for i in range(n_runs):
    state, prob = ours_legendre.demo_qaoa_max_cut4()
    losses.append(ours_legendre.losses_energy.copy())
losses = np.array(losses) + 4.
mean_ = losses.mean(0)
std_ = losses.std(0) 
color = colors[0]
plt.plot(mean_, color=color, label='Ours Legendre')
plt.fill_between(xx, np.maximum(mean_-std_, mean_/3), mean_+std_, color=color, alpha=0.2)
all_mean.append(mean_)
all_std.append(std_)


plt.legend(loc="upper right")
plt.savefig("{}curve_{}.png".format(ours_legendre.log_dir, 'QAOA'))
plt.yscale('log')
plt.savefig("{}curve_{}.png".format(ours_legendre.log_dir, 'QAOA_log'))
# Out:
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -2.0000000
# Objective after step    15: -1.0000000
# Objective after step    20: -3.0000000
# Objective after step    25: -3.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -3.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -3.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -3.0000000
# Optimized (gamma, beta) vectors:
# [[ 1.49606454 -0.7775214 ]
#  [-1.12204975  0.71312153]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -4.0000000
# Objective after step    10: -4.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -3.0000000
# Objective after step    65: -3.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -3.0000000
# Optimized (gamma, beta) vectors:
# [[ 0.94419335  1.08648292]
#  [ 0.98927216 -0.5004187 ]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -1.0000000
# Objective after step    10: -1.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -3.0000000
# Objective after step    40: -3.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -3.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -3.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -3.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -3.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[1.88046174 0.64781009]
#  [1.20959678 0.73848311]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -4.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -2.0000000
# Objective after step    25: -3.0000000
# Objective after step    30: -3.0000000
# Objective after step    35: -3.0000000
# Objective after step    40: -3.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -3.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -3.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -3.0000000
# Objective after step   100: -2.0000000
# Optimized (gamma, beta) vectors:
# [[ 0.47354962 -1.10994843]
#  [-0.26087581  0.17667728]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -2.0000000
# Objective after step    20: -3.0000000
# Objective after step    25: -3.0000000
# Objective after step    30: -3.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -3.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -3.0000000
# Objective after step    60: -3.0000000
# Objective after step    65: -3.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -3.0000000
# Objective after step    90: -3.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -3.0000000
# Optimized (gamma, beta) vectors:
# [[ 0.77749591 -0.5112538 ]
#  [-0.9674291   0.55651678]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -2.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -2.0000000
# Objective after step    25: -3.0000000
# Objective after step    30: -3.0000000
# Objective after step    35: -2.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -3.0000000
# Objective after step    50: -2.0000000
# Objective after step    55: -2.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -2.0000000
# Objective after step    75: -1.0000000
# Objective after step    80: -2.0000000
# Objective after step    85: -3.0000000
# Objective after step    90: -3.0000000
# Objective after step    95: -3.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-1.05570963  0.37202522]
#  [-0.62087541 -0.54857978]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -2.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -3.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -3.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -3.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -3.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -3.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-0.87479129 -1.14240836]
#  [ 2.12003503  0.49317163]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -2.0000000
# Objective after step    10: -1.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -2.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -3.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-0.90534237 -1.0649783 ]
#  [-0.96594693  0.37541968]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -1.0000000
# Objective after step    10: -2.0000000
# Objective after step    15: -3.0000000
# Objective after step    20: -3.0000000
# Objective after step    25: -1.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 0.86680142  1.03675582]
#  [-2.19203316 -0.35608962]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -1.0000000
# Objective after step    10: -2.0000000
# Objective after step    15: -3.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -2.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -3.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -3.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -2.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 1.34579707 -0.69912683]
#  [-1.15774913  0.68155756]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -4.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -2.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -3.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 1.32376513  0.86199307]
#  [-0.41564546 -0.78461956]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -3.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -3.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 1.60078358 -0.77351641]
#  [-1.18091143  0.81138374]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -3.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 0.79918054  1.10679748]
#  [-0.46188859 -0.40822407]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -2.0000000
# Objective after step    15: -2.0000000
# Objective after step    20: -3.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -3.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -2.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -3.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-1.93556204  1.01853882]
#  [-0.34792448  0.93609651]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -2.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -3.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -2.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -3.0000000
# Objective after step    40: -3.0000000
# Objective after step    45: -2.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -3.0000000
# Objective after step    80: -2.0000000
# Objective after step    85: -3.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 1.15474985 -2.11949021]
#  [-0.41951401 -0.76021384]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -1.0000000
# Objective after step    10: -3.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -3.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-1.03915302 -1.14287506]
#  [ 0.62675001  0.43582355]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -2.0000000
# Objective after step    10: -4.0000000
# Objective after step    15: -3.0000000
# Objective after step    20: -2.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -3.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -3.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[ 1.40189036  0.8174098 ]
#  [-0.29726868 -2.50378618]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -4.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -3.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -3.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -3.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-1.60267214  0.71292559]
#  [-0.31586203  0.63902153]]
# Most frequently sampled bit string is: 0101
#
# p=2
# Objective after step     5: -3.0000000
# Objective after step    10: -2.0000000
# Objective after step    15: -4.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -4.0000000
# Objective after step    40: -4.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -4.0000000
# Objective after step    60: -3.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# Objective after step    95: -4.0000000
# Objective after step   100: -4.0000000
# Optimized (gamma, beta) vectors:
# [[-2.04976082  1.02376808]
#  [-0.51581443 -0.61464497]]
# Most frequently sampled bit string is: 1010
#
# p=2
# Objective after step     5: -1.0000000
# Objective after step    10: -4.0000000
# Objective after step    15: -2.0000000
# Objective after step    20: -4.0000000
# Objective after step    25: -4.0000000
# Objective after step    30: -4.0000000
# Objective after step    35: -2.0000000
# Objective after step    40: -3.0000000
# Objective after step    45: -4.0000000
# Objective after step    50: -4.0000000
# Objective after step    55: -3.0000000
# Objective after step    60: -4.0000000
# Objective after step    65: -4.0000000
# Objective after step    70: -4.0000000
# Objective after step    75: -4.0000000
# Objective after step    80: -4.0000000
# Objective after step    85: -4.0000000
# Objective after step    90: -4.0000000
# epoch: 0075, loss: -3.7383, loss_energy: -3.7383
# epoch: 0076, loss: -3.7411, loss_energy: -3.7411
# epoch: 0077, loss: -3.7447, loss_energy: -3.7447
# epoch: 0078, loss: -3.7496, loss_energy: -3.7496
# epoch: 0079, loss: -3.7538, loss_energy: -3.7538
# epoch: 0080, loss: -3.7619, loss_energy: -3.7619
# epoch: 0081, loss: -3.7689, loss_energy: -3.7689
# epoch: 0082, loss: -3.7748, loss_energy: -3.7748
# epoch: 0083, loss: -3.7799, loss_energy: -3.7799
# epoch: 0084, loss: -3.7842, loss_energy: -3.7842
# epoch: 0085, loss: -3.7882, loss_energy: -3.7882
# epoch: 0086, loss: -3.7918, loss_energy: -3.7918
# epoch: 0087, loss: -3.7950, loss_energy: -3.7950
# epoch: 0088, loss: -3.7979, loss_energy: -3.7979
# epoch: 0089, loss: -3.8005, loss_energy: -3.8005
# epoch: 0090, loss: -3.8029, loss_energy: -3.8029
# epoch: 0091, loss: -3.8053, loss_energy: -3.8053
# epoch: 0092, loss: -3.8073, loss_energy: -3.8073
# epoch: 0093, loss: -3.8093, loss_energy: -3.8093
# epoch: 0094, loss: -3.8111, loss_energy: -3.8111
# epoch: 0095, loss: -3.8132, loss_energy: -3.8132
# epoch: 0096, loss: -3.8150, loss_energy: -3.8150
# epoch: 0097, loss: -3.8167, loss_energy: -3.8167
# epoch: 0098, loss: -3.8217, loss_energy: -3.8217
# epoch: 0099, loss: -3.8261, loss_energy: -3.8261
# epoch: 0100, loss: -3.8301, loss_energy: -3.8301
# cut result is  101

# %%
plt.clf()
xx = np.arange(n_epoch)
colors = [
    [0, 0.45, 0.74],
    [0.85, 0.33, 0.1],
    [0.9290, 0.6940, 0.1250],
    [0.4940, 0.1840, 0.5560],
    [0.4660, 0.6740, 0.1880]
]

params = {'legend.fontsize': 25,
          'figure.figsize': (12, 9),
         'axes.labelsize': 30,
         'axes.titlesize': 30,
         'xtick.labelsize':30,
         'ytick.labelsize':30}
plt.rcParams.update(params)
plt.grid(alpha=0.3)


mean_ = all_mean[0]
std_ = all_std[0] 
color = colors[2]
plt.plot(mean_, color=color, label='GRAE', linewidth=4)
plt.fill_between(xx, np.maximum(mean_-std_, mean_/3.0), mean_+std_, color=color, alpha=0.2)
all_mean.append(mean_)
all_std.append(std_)


mean_ = all_mean[1]
std_ = all_std[1] 
color = colors[1]
plt.plot(mean_, color=color, label='Ours Fourier', linewidth=4)
plt.fill_between(xx, np.maximum(mean_-std_, mean_/3.0), mean_+std_, color=color, alpha=0.2)
all_mean.append(mean_)
all_std.append(std_)


mean_ = all_mean[2]
std_ = all_std[2] 
color = colors[0]
plt.plot(mean_, color=color, label='Ours Legendre', linewidth=4)
plt.fill_between(xx, np.maximum(mean_-std_, mean_/3.0), mean_+std_, color=color, alpha=0.2)
all_mean.append(mean_)
all_std.append(std_)

plt.legend(loc="upper right")
plt.savefig("{}curve_{}.png".format(ours_legendre.log_dir, 'QAOA'))
plt.yscale('log')
plt.savefig("{}curve_{}.png".format(ours_legendre.log_dir, 'QAOA_log'))
# plt.savefig("{}_{}.png".format(ours_legendre.log_dir, 'losses_control_log'))
